# %%
df = spark.sql("SELECT * FROM idhamHouse.rumah LIMIT 1000")
df.describe()
display(df)

# %%
df = df.filter(pl.col("region") == "Kuala Lumpur")
# Out:
# StatementMeta(, 07103bbc-8c3c-4b0f-be04-14f29233e9e8, 20, Finished, Available)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df = df.filter(pl.col("region") == "Kuala Lumpur")
#
# NameError: name 'pl' is not defined
